# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the Citipy module to determine city based on latitude and longitude
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify nearest city for each latitude and longitude combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 731

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | quatre cocos
# Processing Record 2 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 1 | tuktoyaktuk
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | alofi
# Processing Record 6 of Set 1 | pemangkat
# Processing Record 7 of Set 1 | college
# Processing Record 8 of Set 1 | hamilton
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | saint george
# Processing Record 11 of Set 1 | outram
# Processing Record 12 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 1 | teguldet
# Processing Record 14 of Set 1 | christchurch
# Processing Record 15 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 1 | port hedland
# Processing Record 17 of Set 1 | kalmunai
# Processing Record 18 of Set 1 | matara
# Processing Record 19 of Set 1 | caravelas
# Processing Record 20 of Set 1 | mar del plata
# Processing Record 21 of Set 1 | ahipara
# Processing Record 22 of Set 1 | camana
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | skelleftea
# Processing Record 25 of Set 1 | cayenne
# Processing Record 26 of Set 1 | lebu
# Processing Record 27 of Set 1 | muros
# Processing Record 28 of Set 1 | cidreira
# Processing Record 29 of Set 1 | muisne
# Processing Record 30 of Set 1 | sargatskoye
# Processing Record 31 of Set 1 | marawi
# Processing Record 32 of Set 1 | barra dos coqueiros
# Processing Record 33 of Set 1 | yerbogachen
# Processing Record 34 of Set 1 | esperance
# Processing Record 35 of Set 1 | narsaq
# Processing Record 36 of Set 1 | karpogory
# Processing Record 37 of Set 1 | torbay
# Processing Record 38 of Set 1 | los llanos de aridane
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | iqaluit
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | carnarvon
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | ancud
# Processing Record 46 of Set 1 | faya
# Processing Record 47 of Set 1 | hithadhoo
# Processing Record 48 of Set 1 | khandyga
# Processing Record 49 of Set 1 | dikson
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | luderitz
# Processing Record 2 of Set 2 | bembereke
# Processing Record 3 of Set 2 | longyearbyen
# Processing Record 4 of Set 2 | outlook
# Processing Record 5 of Set 2 | jamestown
# Processing Record 6 of Set 2 | port elizabeth
# Processing Record 7 of Set 2 | tarumovka
# Processing Record 8 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | tiksi
# Processing Record 11 of Set 2 | castro
# Processing Record 12 of Set 2 | san quintin
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | arraial do cabo
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | kapaa
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | zakamensk
# Processing Record 19 of Set 2 | provideniya
# Processing Record 20 of Set 2 | alta gracia
# Processing Record 21 of Set 2 | vanavara
# Processing Record 22 of Set 2 | hermanus
# Processing Record 23 of Set 2 | punta arenas
# Processing Record 24 of Set 2 | tucuma
# Processing Record 25 of Set 2 | victoria
# Processing Record 26 of Set 2 | mezen
# Processing Record 27 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 28 of Set 2 | saskylakh
# Processing Record 29 of Set 2 | sokoto
# Processing Record 30 of Set 2 | westport
# Processing Record 31 of Set 2 | ixtlahuacan del rio
# Processing Record 32 of Set 2 | chengam
# Processing Record 33 of Set 2 | sao filipe
# Processing Record 34 of Set 2 | kaitangata
# Processing Record 35 of Set 2 | camargo
# Processing Record 36 of Set 2 | vilhena
# Processing Record 37 of Set 2 | nador
# Processing Record 38 of Set 2 | talnakh
# Processing Record 39 of Set 2 | nikolskoye
# Processing Record 40 of Set 2 | peace river
# Processing Record 41 of Set 2 | mataura
# Processing Record 42 of Set 2 | rudabanya
# Processing Record 43 of Set 2 | lilongwe
# Processing Record 44 of Set 2 | vaini
# Processing Record 45 of Set 2 | morondava
# Processing Record 46 of Set 2 | nuuk
# Processing Record 47 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 2 | vanimo
# Processing Record 49 of Set 2 | port alfred
# Processing Record 50 of Set 2 | vagur
# Processing Record 1 of Set 3 | cape town
# Processing Record 2 of Set 3 | honningsvag
# Processing Record 3 of Set 3 | lusambo
# Processing Record 4 of Set 3 | armacao dos buzios
# City not found. Skipping...
# Processing Record 5 of Set 3 | alice springs
# Processing Record 6 of Set 3 | kahului
# Processing Record 7 of Set 3 | halifax
# Processing Record 8 of Set 3 | saint andrews
# Processing Record 9 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 3 | jumla
# Processing Record 11 of Set 3 | hokitika
# Processing Record 12 of Set 3 | albany
# Processing Record 13 of Set 3 | berlevag
# Processing Record 14 of Set 3 | bilibino
# Processing Record 15 of Set 3 | souillac
# Processing Record 16 of Set 3 | iwanai
# Processing Record 17 of Set 3 | tuatapere
# Processing Record 18 of Set 3 | pisco
# Processing Record 19 of Set 3 | klaksvik
# Processing Record 20 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 3 | ayan
# Processing Record 22 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 3 | shimoda
# Processing Record 24 of Set 3 | pangnirtung
# Processing Record 25 of Set 3 | atuona
# Processing Record 26 of Set 3 | sola
# Processing Record 27 of Set 3 | bathsheba
# Processing Record 28 of Set 3 | tulun
# Processing Record 29 of Set 3 | te anau
# Processing Record 30 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 3 | shelburne
# Processing Record 33 of Set 3 | gambo
# Processing Record 34 of Set 3 | kavieng
# Processing Record 35 of Set 3 | kodiak
# Processing Record 36 of Set 3 | skali
# City not found. Skipping...
# Processing Record 37 of Set 3 | chilibre
# Processing Record 38 of Set 3 | faanui
# Processing Record 39 of Set 3 | augustow
# Processing Record 40 of Set 3 | amot
# Processing Record 41 of Set 3 | morant bay
# Processing Record 42 of Set 3 | la ronge
# Processing Record 43 of Set 3 | emirdag
# Processing Record 44 of Set 3 | bom jesus
# Processing Record 45 of Set 3 | puerto ayora
# Processing Record 46 of Set 3 | kieta
# Processing Record 47 of Set 3 | thompson
# Processing Record 48 of Set 3 | deputatskiy
# Processing Record 49 of Set 3 | caucaia
# Processing Record 50 of Set 3 | gewane
# Processing Record 1 of Set 4 | sosnytsya
# Processing Record 2 of Set 4 | koutsouras
# Processing Record 3 of Set 4 | oranjemund
# Processing Record 4 of Set 4 | poum
# Processing Record 5 of Set 4 | samarai
# Processing Record 6 of Set 4 | kununurra
# Processing Record 7 of Set 4 | touros
# Processing Record 8 of Set 4 | walvis bay
# Processing Record 9 of Set 4 | hami
# Processing Record 10 of Set 4 | renukut
# Processing Record 11 of Set 4 | zhoucheng
# Processing Record 12 of Set 4 | tir pol
# City not found. Skipping...
# Processing Record 13 of Set 4 | kasongo-lunda
# Processing Record 14 of Set 4 | lorengau
# Processing Record 15 of Set 4 | busselton
# Processing Record 16 of Set 4 | sovetskiy
# Processing Record 17 of Set 4 | longyan
# Processing Record 18 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 19 of Set 4 | ariquemes
# Processing Record 20 of Set 4 | chuy
# Processing Record 21 of Set 4 | breves
# Processing Record 22 of Set 4 | laguna
# Processing Record 23 of Set 4 | kargasok
# Processing Record 24 of Set 4 | huarmey
# Processing Record 25 of Set 4 | trelew
# Processing Record 26 of Set 4 | fairbanks
# Processing Record 27 of Set 4 | bambous virieux
# Processing Record 28 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 4 | bilma
# Processing Record 30 of Set 4 | qingan
# City not found. Skipping...
# Processing Record 31 of Set 4 | kayseri
# Processing Record 32 of Set 4 | mount gambier
# Processing Record 33 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 4 | adrar
# Processing Record 35 of Set 4 | toumodi
# Processing Record 36 of Set 4 | barrow
# Processing Record 37 of Set 4 | guerrero negro
# Processing Record 38 of Set 4 | aqtobe
# Processing Record 39 of Set 4 | upernavik
# Processing Record 40 of Set 4 | naze
# Processing Record 41 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 42 of Set 4 | ilulissat
# Processing Record 43 of Set 4 | new norfolk
# Processing Record 44 of Set 4 | airai
# Processing Record 45 of Set 4 | severo-yeniseyskiy
# Processing Record 46 of Set 4 | kansanshi
# Processing Record 47 of Set 4 | grand gaube
# Processing Record 48 of Set 4 | mani
# Processing Record 49 of Set 4 | sabang
# Processing Record 50 of Set 4 | beyneu
# Processing Record 1 of Set 5 | aska
# Processing Record 2 of Set 5 | yumen
# Processing Record 3 of Set 5 | the pas
# Processing Record 4 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 5 of Set 5 | isangel
# Processing Record 6 of Set 5 | georgetown
# Processing Record 7 of Set 5 | leningradskiy
# Processing Record 8 of Set 5 | tuy hoa
# Processing Record 9 of Set 5 | itarema
# Processing Record 10 of Set 5 | saint-philippe
# Processing Record 11 of Set 5 | bumba
# Processing Record 12 of Set 5 | grants
# Processing Record 13 of Set 5 | srednekolymsk
# Processing Record 14 of Set 5 | joroan
# Processing Record 15 of Set 5 | kaohsiung
# Processing Record 16 of Set 5 | katsuura
# Processing Record 17 of Set 5 | waycross
# Processing Record 18 of Set 5 | ostrovnoy
# Processing Record 19 of Set 5 | matagami
# Processing Record 20 of Set 5 | udachnyy
# Processing Record 21 of Set 5 | palmer
# Processing Record 22 of Set 5 | bone
# Processing Record 23 of Set 5 | bethel
# Processing Record 24 of Set 5 | tasiilaq
# Processing Record 25 of Set 5 | beringovskiy
# Processing Record 26 of Set 5 | brigantine
# Processing Record 27 of Set 5 | naantali
# Processing Record 28 of Set 5 | bowen
# Processing Record 29 of Set 5 | bugarama
# Processing Record 30 of Set 5 | venadillo
# Processing Record 31 of Set 5 | chokurdakh
# Processing Record 32 of Set 5 | port hardy
# Processing Record 33 of Set 5 | krasnoyarka
# Processing Record 34 of Set 5 | vrangel
# Processing Record 35 of Set 5 | otane
# Processing Record 36 of Set 5 | hoquiam
# Processing Record 37 of Set 5 | kamenka
# Processing Record 38 of Set 5 | hobyo
# Processing Record 39 of Set 5 | broome
# Processing Record 40 of Set 5 | dingle
# Processing Record 41 of Set 5 | jinchang
# Processing Record 42 of Set 5 | wonthaggi
# Processing Record 43 of Set 5 | bud
# Processing Record 44 of Set 5 | marmaron
# City not found. Skipping...
# Processing Record 45 of Set 5 | higuey
# City not found. Skipping...
# Processing Record 46 of Set 5 | hasaki
# Processing Record 47 of Set 5 | muravlenko
# Processing Record 48 of Set 5 | nefteyugansk
# Processing Record 49 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 5 | rocha
# Processing Record 1 of Set 6 | dzilam gonzalez
# Processing Record 2 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 3 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 4 of Set 6 | coreau
# Processing Record 5 of Set 6 | condega
# Processing Record 6 of Set 6 | nome
# Processing Record 7 of Set 6 | lianzhou
# Processing Record 8 of Set 6 | ashqelon
# Processing Record 9 of Set 6 | rawson
# Processing Record 10 of Set 6 | hualmay
# Processing Record 11 of Set 6 | parksepa
# Processing Record 12 of Set 6 | portobelo
# Processing Record 13 of Set 6 | chumphon
# Processing Record 14 of Set 6 | pingliang
# Processing Record 15 of Set 6 | fortuna
# Processing Record 16 of Set 6 | butembo
# Processing Record 17 of Set 6 | ocampo
# Processing Record 18 of Set 6 | san patricio
# Processing Record 19 of Set 6 | olafsvik
# Processing Record 20 of Set 6 | antofagasta
# Processing Record 21 of Set 6 | kilakarai
# Processing Record 22 of Set 6 | moranbah
# Processing Record 23 of Set 6 | tual
# Processing Record 24 of Set 6 | kushmurun
# Processing Record 25 of Set 6 | labuhan
# Processing Record 26 of Set 6 | aklavik
# Processing Record 27 of Set 6 | sao joao da barra
# Processing Record 28 of Set 6 | nuevitas
# Processing Record 29 of Set 6 | kainantu
# Processing Record 30 of Set 6 | melton
# Processing Record 31 of Set 6 | tromso
# Processing Record 32 of Set 6 | arcata
# Processing Record 33 of Set 6 | ponta do sol
# Processing Record 34 of Set 6 | lavrentiya
# Processing Record 35 of Set 6 | pirapemas
# Processing Record 36 of Set 6 | miri
# Processing Record 37 of Set 6 | tura
# Processing Record 38 of Set 6 | kharp
# Processing Record 39 of Set 6 | merke
# Processing Record 40 of Set 6 | canto do buriti
# Processing Record 41 of Set 6 | maniitsoq
# Processing Record 42 of Set 6 | olga
# Processing Record 43 of Set 6 | akyab
# Processing Record 44 of Set 6 | antsohihy
# Processing Record 45 of Set 6 | luis gil perez
# Processing Record 46 of Set 6 | agadez
# Processing Record 47 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 6 | jiwani
# Processing Record 49 of Set 6 | bengkulu
# Processing Record 50 of Set 6 | kruisfontein
# Processing Record 1 of Set 7 | igarka
# Processing Record 2 of Set 7 | indian head
# Processing Record 3 of Set 7 | fresno
# Processing Record 4 of Set 7 | suao
# City not found. Skipping...
# Processing Record 5 of Set 7 | homer
# Processing Record 6 of Set 7 | iquitos
# Processing Record 7 of Set 7 | turmalina
# Processing Record 8 of Set 7 | salalah
# Processing Record 9 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 7 | dibaya
# City not found. Skipping...
# Processing Record 11 of Set 7 | naron
# Processing Record 12 of Set 7 | barkhan
# Processing Record 13 of Set 7 | henties bay
# Processing Record 14 of Set 7 | ust-tarka
# Processing Record 15 of Set 7 | puerto escondido
# Processing Record 16 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 7 | east london
# Processing Record 18 of Set 7 | kizhinga
# Processing Record 19 of Set 7 | balakliya
# Processing Record 20 of Set 7 | salinopolis
# Processing Record 21 of Set 7 | richards bay
# Processing Record 22 of Set 7 | mata grande
# Processing Record 23 of Set 7 | akhtubinsk
# Processing Record 24 of Set 7 | codrington
# Processing Record 25 of Set 7 | kerteh
# City not found. Skipping...
# Processing Record 26 of Set 7 | erenhot
# Processing Record 27 of Set 7 | krasnogorsk
# Processing Record 28 of Set 7 | bentong
# Processing Record 29 of Set 7 | simao
# Processing Record 30 of Set 7 | pevek
# Processing Record 31 of Set 7 | nemuro
# Processing Record 32 of Set 7 | quelimane
# Processing Record 33 of Set 7 | hambantota
# Processing Record 34 of Set 7 | north bend
# Processing Record 35 of Set 7 | omsukchan
# Processing Record 36 of Set 7 | mamallapuram
# Processing Record 37 of Set 7 | vestmannaeyjar
# Processing Record 38 of Set 7 | kudahuvadhoo
# Processing Record 39 of Set 7 | mecca
# Processing Record 40 of Set 7 | valentin gomez farias
# Processing Record 41 of Set 7 | asyut
# Processing Record 42 of Set 7 | cabo san lucas
# Processing Record 43 of Set 7 | malakal
# Processing Record 44 of Set 7 | plainview
# Processing Record 45 of Set 7 | camacha
# Processing Record 46 of Set 7 | washougal
# Processing Record 47 of Set 7 | humaita
# Processing Record 48 of Set 7 | pagman
# City not found. Skipping...
# Processing Record 49 of Set 7 | atar
# Processing Record 50 of Set 7 | somerset east
# Processing Record 1 of Set 8 | state college
# Processing Record 2 of Set 8 | zheshart
# Processing Record 3 of Set 8 | mareeba
# Processing Record 4 of Set 8 | yulara
# Processing Record 5 of Set 8 | tocopilla
# Processing Record 6 of Set 8 | meulaboh
# Processing Record 7 of Set 8 | mount isa
# Processing Record 8 of Set 8 | lukovetskiy
# Processing Record 9 of Set 8 | constitucion
# Processing Record 10 of Set 8 | uige
# Processing Record 11 of Set 8 | saldanha
# Processing Record 12 of Set 8 | safranbolu
# Processing Record 13 of Set 8 | antalaha
# Processing Record 14 of Set 8 | flagstaff
# Processing Record 15 of Set 8 | urubicha
# Processing Record 16 of Set 8 | port-gentil
# Processing Record 17 of Set 8 | ust-maya
# Processing Record 18 of Set 8 | ixtapa
# Processing Record 19 of Set 8 | margate
# Processing Record 20 of Set 8 | emerald
# Processing Record 21 of Set 8 | cockburn town
# Processing Record 22 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 23 of Set 8 | contratacion
# Processing Record 24 of Set 8 | lazaro cardenas
# Processing Record 25 of Set 8 | alba
# Processing Record 26 of Set 8 | vitim
# Processing Record 27 of Set 8 | luba
# Processing Record 28 of Set 8 | lodja
# Processing Record 29 of Set 8 | kandrian
# Processing Record 30 of Set 8 | verkhoyansk
# Processing Record 31 of Set 8 | alekseyevsk
# Processing Record 32 of Set 8 | katherine
# Processing Record 33 of Set 8 | hirara
# Processing Record 34 of Set 8 | poya
# Processing Record 35 of Set 8 | cherskiy
# Processing Record 36 of Set 8 | avera
# Processing Record 37 of Set 8 | cordele
# Processing Record 38 of Set 8 | gilgit
# Processing Record 39 of Set 8 | tucupita
# Processing Record 40 of Set 8 | san cristobal
# Processing Record 41 of Set 8 | changli
# Processing Record 42 of Set 8 | saint-augustin
# Processing Record 43 of Set 8 | mont-dore
# Processing Record 44 of Set 8 | sibanicu
# Processing Record 45 of Set 8 | sobolevo
# Processing Record 46 of Set 8 | kumluca
# Processing Record 47 of Set 8 | maldonado
# Processing Record 48 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 8 | odweyne
# Processing Record 50 of Set 8 | marystown
# Processing Record 1 of Set 9 | floriano
# Processing Record 2 of Set 9 | saint-paul
# Processing Record 3 of Set 9 | kikwit
# Processing Record 4 of Set 9 | olbia
# Processing Record 5 of Set 9 | daru
# Processing Record 6 of Set 9 | robore
# Processing Record 7 of Set 9 | paso de carrasco
# Processing Record 8 of Set 9 | haines junction
# Processing Record 9 of Set 9 | tautira
# Processing Record 10 of Set 9 | bermeo
# Processing Record 11 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 9 | tigil
# Processing Record 13 of Set 9 | ust-kuyga
# Processing Record 14 of Set 9 | kavaratti
# Processing Record 15 of Set 9 | kismayo
# Processing Record 16 of Set 9 | pitsunda
# Processing Record 17 of Set 9 | oksbol
# Processing Record 18 of Set 9 | northam
# Processing Record 19 of Set 9 | riyadh
# Processing Record 20 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 9 | uttamapalaiyam
# Processing Record 22 of Set 9 | ipsos
# City not found. Skipping...
# Processing Record 23 of Set 9 | sao geraldo do araguaia
# Processing Record 24 of Set 9 | sitka
# Processing Record 25 of Set 9 | yuncheng
# Processing Record 26 of Set 9 | koulamoutou
# Processing Record 27 of Set 9 | sakakah
# Processing Record 28 of Set 9 | luena
# Processing Record 29 of Set 9 | bardiyah
# Processing Record 30 of Set 9 | armidale
# Processing Record 31 of Set 9 | sur
# Processing Record 32 of Set 9 | benguela
# Processing Record 33 of Set 9 | acapulco
# Processing Record 34 of Set 9 | camalu
# Processing Record 35 of Set 9 | padang
# Processing Record 36 of Set 9 | surgut
# Processing Record 37 of Set 9 | mitsamiouli
# Processing Record 38 of Set 9 | geraldton
# Processing Record 39 of Set 9 | moose jaw
# Processing Record 40 of Set 9 | takaka
# Processing Record 41 of Set 9 | grindavik
# Processing Record 42 of Set 9 | ca mau
# Processing Record 43 of Set 9 | namibe
# Processing Record 44 of Set 9 | tomari
# Processing Record 45 of Set 9 | havre-saint-pierre
# Processing Record 46 of Set 9 | barra do garcas
# Processing Record 47 of Set 9 | byron bay
# Processing Record 48 of Set 9 | shirpur
# Processing Record 49 of Set 9 | madang
# Processing Record 50 of Set 9 | skjervoy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [58], in <cell line: 12>()
#      16     set_count += 1
#      17     record_count = 1
# ---> 18     time.sleep(60)
#      20 # Create endpoint URL with each city.
#      21 city_url = url + "&q=" + city.replace(" ","+")
#
# KeyboardInterrupt:

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.to_csv("cities.csv",index_label = "City_ID")
city_data_df.head()
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Cherskiy      RU  68.7500  161.3000      0.03        91          99
# 1  Saldanha      ZA -33.0117   17.9442     61.65        83          19
# 2   Ushuaia      AR -54.8000  -68.3000     46.06        81          40
# 3    Dikson      RU  73.5069   80.5464     26.94        83         100
# 4    Barmer      IN  25.7500   71.3833     97.32         4           0
#
#    Wind Speed Current Description
# 0        8.03     overcast clouds
# 1       10.83          few clouds
# 2        6.91    scattered clouds
# 3       16.06     overcast clouds
# 4        4.92           clear sky

# %%
city_data_df = pd.read_csv("cities.csv")

# %%
# Deliverable 1-8. Export the City_Data into a CSV.
city_data_df.to_csv('WeatherPy_Database.csv',index_label='City_ID')
